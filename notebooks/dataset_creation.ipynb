# %% [markdown]
# <a href="https://colab.research.google.com/github/FerasAfi/hazardous-asteroids-prediction-ml/blob/main/notebooks/dataset_creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 200)

# %%
asteroids = pd.read_json('/content/drive/MyDrive/Colab Notebooks/Personal/Meteors/mpcorb_extended.json')

hazardous_asteroids = pd.read_json('/content/drive/MyDrive/Colab Notebooks/Personal/Meteors/pha_extended.json')

# %%
asteroids.head()
# Out:
#    Critical_list_numbered_object_flag     H     G  Num_obs   rms  U  \
# 0                                 1.0  3.35  0.15   7369.0  0.69  0
# 1                                 1.0  4.11  0.15   9021.0  0.64  0
# 2                                 1.0  5.19  0.15   7565.0  0.67  0
# 3                                 1.0  3.25  0.15   7543.0  0.69  0
# 4                                 1.0  6.97  0.15   3339.0  0.79  0
#
#    Arc_years Perturbers Perturbers_2 Number     Name Principal_desig  \
# 0  1801-2025        M-v          30k    (1)    Ceres         A801 AA
# 1  1804-2025        M-c          28k    (2)   Pallas         A802 FA
# 2  1804-2025        M-v          3Ek    (3)     Juno         A804 RA
# 3  1821-2025        M-p          18k    (4)    Vesta         A807 FA
# 4  1845-2025        M-v          3Ek    (5)  Astraea         A845 XA
#
#          Other_desigs      Epoch          M       Peri       Node         i  \
# 0  [A899 OF, 1943 XB]  2461000.5  231.53975   73.29974   80.24963  10.58789
# 1                 NaN  2461000.5  211.52977  310.93340  172.88859  34.92833
# 2                 NaN  2461000.5  217.59095  247.88367  169.81989  12.98604
# 3                 NaN  2461000.5   26.80968  151.53712  103.70232   7.14406
# 4           [1969 SE]  2461000.5  133.86760  359.34517  141.44862   5.35925
#
#           e         n         a        Ref  Num_opps   Computer Hex_flags  \
# 0  0.079576  0.214297  2.765616  MPO950947       126  MPCORBFIT      4000
# 1  0.230643  0.213797  2.769926  E2025-V46       124  MPCORBFIT      4000
# 2  0.255826  0.225799  2.670879  MPO937415       118  MPCORBFIT      4000
# 3  0.090168  0.271588  2.361541  MPO925791       112   MPCLINUX      4000
# 4  0.187509  0.238269  2.576865  MPO950947        89  MPCORBFIT      4000
#
#      Last_obs            Tp  Orbital_period  Perihelion_dist  Aphelion_dist  \
# 0  2025-10-03  2.461600e+06        4.599258         2.545538       2.985693
# 1  2025-11-05  2.461695e+06        4.610014         2.131062       3.408790
# 2  2025-08-08  2.461631e+06        4.364971         1.987599       3.354159
# 3  2025-06-24  2.460902e+06        3.629053         2.148607       2.574476
# 4  2025-10-06  2.460439e+06        4.136542         2.093680       3.060049
#
#    Semilatus_rectum  Synodic_period Orbit_type  NEO_flag  One_km_NEO_flag  \
# 0          1.374051        1.277835        MBA       NaN              NaN
# 1          1.311288        1.277007        MBA       NaN              NaN
# 2          1.248039        1.297179        MBA       NaN              NaN
# 3          1.171171        1.380365        MBA       NaN              NaN
# 4          1.243132        1.318823        MBA       NaN              NaN
#
#    PHA_flag  One_opposition_object_flag  Arc_length
# 0       NaN                         NaN         NaN
# 1       NaN                         NaN         NaN
# 2       NaN                         NaN         NaN
# 3       NaN                         NaN         NaN
# 4       NaN                         NaN         NaN

# %%
asteroids.shape
# Out:
# (1477090, 38)

# %%
asteroids.columns
# Out:
# Index(['Critical_list_numbered_object_flag', 'H', 'G', 'Num_obs', 'rms', 'U',
#        'Arc_years', 'Perturbers', 'Perturbers_2', 'Number', 'Name',
#        'Principal_desig', 'Other_desigs', 'Epoch', 'M', 'Peri', 'Node', 'i',
#        'e', 'n', 'a', 'Ref', 'Num_opps', 'Computer', 'Hex_flags', 'Last_obs',
#        'Tp', 'Orbital_period', 'Perihelion_dist', 'Aphelion_dist',
#        'Semilatus_rectum', 'Synodic_period', 'Orbit_type', 'NEO_flag',
#        'One_km_NEO_flag', 'PHA_flag', 'One_opposition_object_flag',
#        'Arc_length'],
#       dtype='object')

# %%
hazardous_asteroids.head()
# Out:
#    NEO_flag  One_km_NEO_flag  PHA_flag      H     G  Num_obs   rms  U  \
# 0       1.0              1.0       1.0  16.53  0.15     1842  0.63  0
# 1       1.0              1.0       1.0  15.26  0.15     8261  0.51  0
# 2       1.0              1.0       1.0  16.08  0.09     3129  0.72  0
# 3       1.0              1.0       1.0  15.28  0.15     2264  0.64  0
# 4       1.0              NaN       1.0  18.69  0.15      158  0.90  0
#
#    Arc_years Perturbers Perturbers_2  Number        Name Principal_desig  \
# 0  1949-2025        M-v          3Ek  (1566)      Icarus         1949 MA
# 1  1951-2025        M-v          3Ek  (1620)  Geographos         1951 RA
# 2  1930-2025        M-v          3Ek  (1862)      Apollo         1932 HA
# 3  1973-2025        M-v          3Ek  (1981)       Midas         1973 EA
# 4  1936-2025        M-v          3Ek  (2101)      Adonis         1936 CA
#
#        Epoch          M       Peri       Node         i         e         n  \
# 0  2461000.5  153.07893   31.43821   87.95243  22.80320  0.827006  0.880548
# 1  2461000.5  212.92045  277.01839  337.14079  13.33580  0.335512  0.708833
# 2  2461000.5  113.88454  286.05088   35.54163   6.35140  0.559918  0.552483
# 3  2461000.5   65.34754  267.84424  356.79391  39.82339  0.650496  0.416332
# 4  2461000.5   24.47917   43.71160  349.40534   1.31997  0.764127  0.384185
#
#           a        Ref  Num_opps   Computer Hex_flags    Last_obs  \
# 0  1.078038  MPO950970        43   MPCLINUX      9803  2025-08-18
# 1  1.245777  E2025-V79        41  MPCORBFIT      9803  2025-11-10
# 2  1.470924  E2025-UO9        37  MPCORBFIT      9803  2025-10-27
# 3  1.776272  E2025-V79        28  MPCORBFIT      9803  2025-11-10
# 4  1.874025  MPO937442        12   MPCLINUX      8803  2025-07-19
#
#              Tp  Orbital_period  Perihelion_dist  Aphelion_dist  \
# 0  2.460827e+06        1.119312         0.186494       1.969581
# 1  2.461208e+06        1.390466         0.827804       1.663750
# 2  2.460794e+06        1.783961         0.647327       2.294520
# 3  2.460844e+06        2.367358         0.620815       2.931728
# 4  2.460937e+06        2.565448         0.442031       3.306019
#
#    Semilatus_rectum  Synodic_period Orbit_type Other_desigs  \
# 0          0.170363        9.381419     Apollo          NaN
# 1          0.552771        3.561042     Apollo   [1983 CY3]
# 2          0.504889        2.275574     Apollo          NaN
# 3          0.512326        1.731337     Apollo          NaN
# 4          0.389900        1.638795     Apollo          NaN
#
#    One_opposition_object_flag  Arc_length
# 0                         NaN         NaN
# 1                         NaN         NaN
# 2                         NaN         NaN
# 3                         NaN         NaN
# 4                         NaN         NaN

# %%
hazardous_asteroids.shape
# Out:
# (2505, 37)

# %%
hazardous_asteroids.columns
# Out:
# Index(['NEO_flag', 'One_km_NEO_flag', 'PHA_flag', 'H', 'G', 'Num_obs', 'rms',
#        'U', 'Arc_years', 'Perturbers', 'Perturbers_2', 'Number', 'Name',
#        'Principal_desig', 'Epoch', 'M', 'Peri', 'Node', 'i', 'e', 'n', 'a',
#        'Ref', 'Num_opps', 'Computer', 'Hex_flags', 'Last_obs', 'Tp',
#        'Orbital_period', 'Perihelion_dist', 'Aphelion_dist',
#        'Semilatus_rectum', 'Synodic_period', 'Orbit_type', 'Other_desigs',
#        'One_opposition_object_flag', 'Arc_length'],
#       dtype='object')

# %%
asteroids['Principal_desig'].isin(hazardous_asteroids['Principal_desig']).value_counts()
# Out:
# Principal_desig
# False    1474585
# True        2505
# Name: count, dtype: int64

# %%
asteroids_cols = asteroids.columns
hazardous_asteroids_col = hazardous_asteroids.columns

print('The columns in Asteroids but not in Hazerous Astorids:')
for col in asteroids_cols:
  if col not in hazardous_asteroids_col:
    print(col)

print("#"*120)

print('The columns that are in Hazerous Astorids but not in Asteroids:')
for col in hazardous_asteroids_col:
  if col not in asteroids_cols:
    print(col)
# Out:
# The columns in Asteroids but not in Hazerous Astorids:
# Critical_list_numbered_object_flag
# ########################################################################################################################
# The columns that are in Hazerous Astorids but not in Asteroids:

# %%
asteroids.drop('Critical_list_numbered_object_flag', axis=1, inplace=True)

# %%
asteroids_cols = asteroids.columns
hazardous_asteroids_col = hazardous_asteroids.columns

print('The columns in Asteroids but not in Hazerous Astorids:')
for col in asteroids_cols:
  if col not in hazardous_asteroids_col:
    print(col)

print("#"*120)

print('The columns that are in Hazerous Astorids but not in Asteroids:')
for col in hazardous_asteroids_col:
  if col not in asteroids_cols:
    print(col)
# Out:
# The columns in Asteroids but not in Hazerous Astorids:
# ########################################################################################################################
# The columns that are in Hazerous Astorids but not in Asteroids:

# %%
asteroids_cols = asteroids.columns
hazardous_asteroids_col = hazardous_asteroids.columns

for i, col in enumerate(asteroids_cols):
    print(f'{col}: index_in_asteroids={i}, index_in_hazardous={hazardous_asteroids_col.get_loc(col)}')
# Out:
# H: index_in_asteroids=0, index_in_hazardous=3
# G: index_in_asteroids=1, index_in_hazardous=4
# Num_obs: index_in_asteroids=2, index_in_hazardous=5
# rms: index_in_asteroids=3, index_in_hazardous=6
# U: index_in_asteroids=4, index_in_hazardous=7
# Arc_years: index_in_asteroids=5, index_in_hazardous=8
# Perturbers: index_in_asteroids=6, index_in_hazardous=9
# Perturbers_2: index_in_asteroids=7, index_in_hazardous=10
# Number: index_in_asteroids=8, index_in_hazardous=11
# Name: index_in_asteroids=9, index_in_hazardous=12
# Principal_desig: index_in_asteroids=10, index_in_hazardous=13
# Other_desigs: index_in_asteroids=11, index_in_hazardous=34
# Epoch: index_in_asteroids=12, index_in_hazardous=14
# M: index_in_asteroids=13, index_in_hazardous=15
# Peri: index_in_asteroids=14, index_in_hazardous=16
# Node: index_in_asteroids=15, index_in_hazardous=17
# i: index_in_asteroids=16, index_in_hazardous=18
# e: index_in_asteroids=17, index_in_hazardous=19
# n: index_in_asteroids=18, index_in_hazardous=20
# a: index_in_asteroids=19, index_in_hazardous=21
# Ref: index_in_asteroids=20, index_in_hazardous=22
# Num_opps: index_in_asteroids=21, index_in_hazardous=23
# Computer: index_in_asteroids=22, index_in_hazardous=24
# Hex_flags: index_in_asteroids=23, index_in_hazardous=25
# Last_obs: index_in_asteroids=24, index_in_hazardous=26
# Tp: index_in_asteroids=25, index_in_hazardous=27
# Orbital_period: index_in_asteroids=26, index_in_hazardous=28
# Perihelion_dist: index_in_asteroids=27, index_in_hazardous=29
# Aphelion_dist: index_in_asteroids=28, index_in_hazardous=30
# Semilatus_rectum: index_in_asteroids=29, index_in_hazardous=31
# Synodic_period: index_in_asteroids=30, index_in_hazardous=32
# Orbit_type: index_in_asteroids=31, index_in_hazardous=33
# NEO_flag: index_in_asteroids=32, index_in_hazardous=0
# One_km_NEO_flag: index_in_asteroids=33, index_in_hazardous=1
# PHA_flag: index_in_asteroids=34, index_in_hazardous=2
# One_opposition_object_flag: index_in_asteroids=35, index_in_hazardous=35
# Arc_length: index_in_asteroids=36, index_in_hazardous=36

# %%
hazardous_asteroids = hazardous_asteroids[asteroids.columns]

# %%
hazardous_asteroids.head()
# Out:
#        H     G  Num_obs   rms  U  Arc_years Perturbers Perturbers_2  Number  \
# 0  16.53  0.15     1842  0.63  0  1949-2025        M-v          3Ek  (1566)
# 1  15.26  0.15     8261  0.51  0  1951-2025        M-v          3Ek  (1620)
# 2  16.08  0.09     3129  0.72  0  1930-2025        M-v          3Ek  (1862)
# 3  15.28  0.15     2264  0.64  0  1973-2025        M-v          3Ek  (1981)
# 4  18.69  0.15      158  0.90  0  1936-2025        M-v          3Ek  (2101)
#
#          Name Principal_desig Other_desigs      Epoch          M       Peri  \
# 0      Icarus         1949 MA          NaN  2461000.5  153.07893   31.43821
# 1  Geographos         1951 RA   [1983 CY3]  2461000.5  212.92045  277.01839
# 2      Apollo         1932 HA          NaN  2461000.5  113.88454  286.05088
# 3       Midas         1973 EA          NaN  2461000.5   65.34754  267.84424
# 4      Adonis         1936 CA          NaN  2461000.5   24.47917   43.71160
#
#         Node         i         e         n         a        Ref  Num_opps  \
# 0   87.95243  22.80320  0.827006  0.880548  1.078038  MPO950970        43
# 1  337.14079  13.33580  0.335512  0.708833  1.245777  E2025-V79        41
# 2   35.54163   6.35140  0.559918  0.552483  1.470924  E2025-UO9        37
# 3  356.79391  39.82339  0.650496  0.416332  1.776272  E2025-V79        28
# 4  349.40534   1.31997  0.764127  0.384185  1.874025  MPO937442        12
#
#     Computer Hex_flags    Last_obs            Tp  Orbital_period  \
# 0   MPCLINUX      9803  2025-08-18  2.460827e+06        1.119312
# 1  MPCORBFIT      9803  2025-11-10  2.461208e+06        1.390466
# 2  MPCORBFIT      9803  2025-10-27  2.460794e+06        1.783961
# 3  MPCORBFIT      9803  2025-11-10  2.460844e+06        2.367358
# 4   MPCLINUX      8803  2025-07-19  2.460937e+06        2.565448
#
#    Perihelion_dist  Aphelion_dist  Semilatus_rectum  Synodic_period  \
# 0         0.186494       1.969581          0.170363        9.381419
# 1         0.827804       1.663750          0.552771        3.561042
# 2         0.647327       2.294520          0.504889        2.275574
# 3         0.620815       2.931728          0.512326        1.731337
# 4         0.442031       3.306019          0.389900        1.638795
#
#   Orbit_type  NEO_flag  One_km_NEO_flag  PHA_flag  One_opposition_object_flag  \
# 0     Apollo       1.0              1.0       1.0                         NaN
# 1     Apollo       1.0              1.0       1.0                         NaN
# 2     Apollo       1.0              1.0       1.0                         NaN
# 3     Apollo       1.0              1.0       1.0                         NaN
# 4     Apollo       1.0              NaN       1.0                         NaN
#
#    Arc_length
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
asteroids = asteroids[~asteroids['Principal_desig'].isin(hazardous_asteroids['Principal_desig'])]

# %%
asteroids.shape
# Out:
# (1474585, 37)

# %%
asteroids['hazerdous'] = np.zeros(1474585, dtype=int)

# %%
asteroids.head()
# Out:
#       H     G  Num_obs   rms  U  Arc_years Perturbers Perturbers_2 Number  \
# 0  3.35  0.15   7369.0  0.69  0  1801-2025        M-v          30k    (1)
# 1  4.11  0.15   9021.0  0.64  0  1804-2025        M-c          28k    (2)
# 2  5.19  0.15   7565.0  0.67  0  1804-2025        M-v          3Ek    (3)
# 3  3.25  0.15   7543.0  0.69  0  1821-2025        M-p          18k    (4)
# 4  6.97  0.15   3339.0  0.79  0  1845-2025        M-v          3Ek    (5)
#
#       Name Principal_desig        Other_desigs      Epoch          M  \
# 0    Ceres         A801 AA  [A899 OF, 1943 XB]  2461000.5  231.53975
# 1   Pallas         A802 FA                 NaN  2461000.5  211.52977
# 2     Juno         A804 RA                 NaN  2461000.5  217.59095
# 3    Vesta         A807 FA                 NaN  2461000.5   26.80968
# 4  Astraea         A845 XA           [1969 SE]  2461000.5  133.86760
#
#         Peri       Node         i         e         n         a        Ref  \
# 0   73.29974   80.24963  10.58789  0.079576  0.214297  2.765616  MPO950947
# 1  310.93340  172.88859  34.92833  0.230643  0.213797  2.769926  E2025-V46
# 2  247.88367  169.81989  12.98604  0.255826  0.225799  2.670879  MPO937415
# 3  151.53712  103.70232   7.14406  0.090168  0.271588  2.361541  MPO925791
# 4  359.34517  141.44862   5.35925  0.187509  0.238269  2.576865  MPO950947
#
#    Num_opps   Computer Hex_flags    Last_obs            Tp  Orbital_period  \
# 0       126  MPCORBFIT      4000  2025-10-03  2.461600e+06        4.599258
# 1       124  MPCORBFIT      4000  2025-11-05  2.461695e+06        4.610014
# 2       118  MPCORBFIT      4000  2025-08-08  2.461631e+06        4.364971
# 3       112   MPCLINUX      4000  2025-06-24  2.460902e+06        3.629053
# 4        89  MPCORBFIT      4000  2025-10-06  2.460439e+06        4.136542
#
#    Perihelion_dist  Aphelion_dist  Semilatus_rectum  Synodic_period  \
# 0         2.545538       2.985693          1.374051        1.277835
# 1         2.131062       3.408790          1.311288        1.277007
# 2         1.987599       3.354159          1.248039        1.297179
# 3         2.148607       2.574476          1.171171        1.380365
# 4         2.093680       3.060049          1.243132        1.318823
#
#   Orbit_type  NEO_flag  One_km_NEO_flag  PHA_flag  One_opposition_object_flag  \
# 0        MBA       NaN              NaN       NaN                         NaN
# 1        MBA       NaN              NaN       NaN                         NaN
# 2        MBA       NaN              NaN       NaN                         NaN
# 3        MBA       NaN              NaN       NaN                         NaN
# 4        MBA       NaN              NaN       NaN                         NaN
#
#    Arc_length  hazerdous
# 0         NaN          0
# 1         NaN          0
# 2         NaN          0
# 3         NaN          0
# 4         NaN          0

# %%
hazardous_asteroids['hazerdous'] = np.ones(2505, dtype=int)

# %%
hazardous_asteroids.head()
# Out:
#        H     G  Num_obs   rms  U  Arc_years Perturbers Perturbers_2  Number  \
# 0  16.53  0.15     1842  0.63  0  1949-2025        M-v          3Ek  (1566)
# 1  15.26  0.15     8261  0.51  0  1951-2025        M-v          3Ek  (1620)
# 2  16.08  0.09     3129  0.72  0  1930-2025        M-v          3Ek  (1862)
# 3  15.28  0.15     2264  0.64  0  1973-2025        M-v          3Ek  (1981)
# 4  18.69  0.15      158  0.90  0  1936-2025        M-v          3Ek  (2101)
#
#          Name Principal_desig Other_desigs      Epoch          M       Peri  \
# 0      Icarus         1949 MA          NaN  2461000.5  153.07893   31.43821
# 1  Geographos         1951 RA   [1983 CY3]  2461000.5  212.92045  277.01839
# 2      Apollo         1932 HA          NaN  2461000.5  113.88454  286.05088
# 3       Midas         1973 EA          NaN  2461000.5   65.34754  267.84424
# 4      Adonis         1936 CA          NaN  2461000.5   24.47917   43.71160
#
#         Node         i         e         n         a        Ref  Num_opps  \
# 0   87.95243  22.80320  0.827006  0.880548  1.078038  MPO950970        43
# 1  337.14079  13.33580  0.335512  0.708833  1.245777  E2025-V79        41
# 2   35.54163   6.35140  0.559918  0.552483  1.470924  E2025-UO9        37
# 3  356.79391  39.82339  0.650496  0.416332  1.776272  E2025-V79        28
# 4  349.40534   1.31997  0.764127  0.384185  1.874025  MPO937442        12
#
#     Computer Hex_flags    Last_obs            Tp  Orbital_period  \
# 0   MPCLINUX      9803  2025-08-18  2.460827e+06        1.119312
# 1  MPCORBFIT      9803  2025-11-10  2.461208e+06        1.390466
# 2  MPCORBFIT      9803  2025-10-27  2.460794e+06        1.783961
# 3  MPCORBFIT      9803  2025-11-10  2.460844e+06        2.367358
# 4   MPCLINUX      8803  2025-07-19  2.460937e+06        2.565448
#
#    Perihelion_dist  Aphelion_dist  Semilatus_rectum  Synodic_period  \
# 0         0.186494       1.969581          0.170363        9.381419
# 1         0.827804       1.663750          0.552771        3.561042
# 2         0.647327       2.294520          0.504889        2.275574
# 3         0.620815       2.931728          0.512326        1.731337
# 4         0.442031       3.306019          0.389900        1.638795
#
#   Orbit_type  NEO_flag  One_km_NEO_flag  PHA_flag  One_opposition_object_flag  \
# 0     Apollo       1.0              1.0       1.0                         NaN
# 1     Apollo       1.0              1.0       1.0                         NaN
# 2     Apollo       1.0              1.0       1.0                         NaN
# 3     Apollo       1.0              1.0       1.0                         NaN
# 4     Apollo       1.0              NaN       1.0                         NaN
#
#    Arc_length  hazerdous
# 0         NaN          1
# 1         NaN          1
# 2         NaN          1
# 3         NaN          1
# 4         NaN          1

# %%
df = pd.concat([asteroids, hazardous_asteroids])
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
df.shape
# Out:
# (1477090, 38)

# %%
df.tail()
# Out:
#              H     G  Num_obs   rms  U  Arc_years Perturbers Perturbers_2  \
# 1477085  16.80  0.15    670.0  0.87  0  1977-2025        M-v          3Ek
# 1477086  16.98  0.15     33.0  0.43  1  2007-2025        M-v          3Ek
# 1477087  16.79  0.15    598.0  0.80  0  1998-2025        M-v          3Ek
# 1477088  17.54  0.15    136.0  0.88  0  2005-2024        M-v          3Ek
# 1477089  16.54  0.15    706.0  0.79  0  1992-2025        M-v          3Ek
#
#            Number Name Principal_desig Other_desigs      Epoch          M  \
# 1477085  (259474)  NaN      2003 SX169          NaN  2461000.5  340.63291
# 1477086       NaN  NaN       2023 VP11          NaN  2461000.5   92.19696
# 1477087  (132045)  NaN      2002 CY132          NaN  2461000.5  107.25030
# 1477088  (671984)  NaN      2014 QU324  [2016 AP15]  2461000.5  164.74466
# 1477089  (122071)  NaN        2000 HZ9          NaN  2461000.5  282.05058
#
#               Peri       Node        i         e         n         a  \
# 1477085   78.86674  221.01017  6.01269  0.123230  0.302369  2.198424
# 1477086  311.33257  106.21730  4.29026  0.177540  0.124562  3.970799
# 1477087   27.72002  194.96491  0.79093  0.135780  0.267411  2.386068
# 1477088  238.79382   81.82374  3.15423  0.069401  0.206451  2.835250
# 1477089  164.07538   58.39492  3.33323  0.153154  0.261206  2.423712
#
#                Ref  Num_opps   Computer Hex_flags    Last_obs            Tp  \
# 1477085  MPO916193        17   MPCLINUX      0000  2025-05-15  2.461065e+06
# 1477086  MPO907375         6   MPCLINUX      0008  2025-01-22  2.460260e+06
# 1477087  MPO952068        18  MPCORBFIT      0000  2025-09-15  2.460599e+06
# 1477088  MPO892538        10   MPCLINUX      0000  2024-12-23  2.460203e+06
# 1477089  E2025-UO9        20  MPCORBFIT      0000  2025-10-27  2.461299e+06
#
#          Orbital_period  Perihelion_dist  Aphelion_dist  Semilatus_rectum  \
# 1477085        3.259622         1.927511       2.469337          1.082520
# 1477086        7.912557         3.265822       4.675776          1.922818
# 1477087        3.685737         2.062087       2.710050          1.171039
# 1477088        4.774052         2.638480       3.032020          1.410797
# 1477089        3.773301         2.052510       2.794914          1.183430
#
#          Synodic_period Orbit_type  NEO_flag  One_km_NEO_flag  PHA_flag  \
# 1477085        1.442552        MBA       NaN              NaN       NaN
# 1477086        1.144664      Hilda       NaN              NaN       NaN
# 1477087        1.372337        MBA       NaN              NaN       NaN
# 1477088        1.264967        MBA       NaN              NaN       NaN
# 1477089        1.360581        MBA       NaN              NaN       NaN
#
#          One_opposition_object_flag  Arc_length  hazerdous
# 1477085                         NaN         NaN          0
# 1477086                         NaN         NaN          0
# 1477087                         NaN         NaN          0
# 1477088                         NaN         NaN          0
# 1477089                         NaN         NaN          0

# %%
df['hazerdous'].value_counts()
# Out:
# hazerdous
# 0    1474585
# 1       2505
# Name: count, dtype: int64
